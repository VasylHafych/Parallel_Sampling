# %%
using IntervalSets, Distributions, MultivariateStats,  ValueShapes, TypedTables
using Random, LinearAlgebra, Statistics, Distributions, StatsBase, ArraysOfArrays
using JLD2, HDF5, CSV, LaTeXStrings
using Measurements, HypothesisTests

# %%
using Flux
using Flux: logitcrossentropy, normalise, onecold, onehotbatch, crossentropy, throttle
using Statistics: mean
using Parameters: @with_kw
using Flux: @epochs

# %%
using PyPlot
using BAT

# %%
function Statistics.cov(dist::BAT.FunnelDistribution)
    cov(nestedview(rand(BAT.bat_determ_rng(), BAT.sampler(dist), 10^5)))
end

accuracy(x, y, model) = mean(onecold(model(x)) .== onecold(y))

# Function to build confusion matrix
function confusion_matrix(X, y, model)
    ŷ = onehotbatch(onecold(model(X)), 0:1)
    # onecold([true, false, false], [:a, :b, :c]) -> :a
    # onehotbatch -> matrix of cathegorical variables
    y * transpose(ŷ)
end

loss(x, y) = crossentropy(model(x), y) 

evalcb = () -> begin 
    los_train = loss(x_train, y_train)
    lost_test = loss(x_test, y_test)
    @info(los_train, lost_test)
end
# Out:
# #9 (generic function with 1 method)

# %%
convergence = BrooksGelmanConvergence(
    threshold = 1.1, #Change up
    corrected = false
)

init = MCMCInitStrategy(
    init_tries_per_chain = 8..128,
    max_nsamples_init = 250,
    max_nsteps_init = 250,
    max_time_init = 50
)

burnin = MCMCBurninStrategy(
    max_nsamples_per_cycle = 1000,
    max_nsteps_per_cycle = 10000,
    max_time_per_cycle = 250,
    max_ncycles = 100
)

n_dim = 20
algorithm = MetropolisHastings()
n_chains = 10
n_samples = 10^4
# Out:
# 10000

# %%
dis = BAT.FunnelDistribution(a=0.5, b=0.5, n=n_dim)
# Out:
# BAT.FunnelDistribution(a=0.5, b=0.5, n=20)

# %%
iid_sample = bat_sample(dis, n_samples*n_chains).result;

mcmc_sample = bat_sample(
    dis, 
    (n_samples, n_chains),
    algorithm,
    max_time = Inf,
    init = init,
    burnin = burnin,
    convergence = convergence,
    strict = true,
    filter = true
).result;
# Out:
# ┌ Info: Initializing new RNG of type Random123.Philox4x{UInt64,10}
# └ @ BAT /Users/vhafych/MPP-Server/gitrepos/BAT.jl/src/algotypes/bat_default.jl:44
# ┌ Info: Using sampling algorithm IIDSampling()
# └ @ BAT /Users/vhafych/MPP-Server/gitrepos/BAT.jl/src/algotypes/bat_default.jl:44
# ┌ Info: Initializing new RNG of type Random123.Philox4x{UInt64,10}
# └ @ BAT /Users/vhafych/MPP-Server/gitrepos/BAT.jl/src/algotypes/bat_default.jl:44
# ┌ Info: Trying to generate 10 viable MCMC chain(s).
# └ @ BAT /Users/vhafych/MPP-Server/gitrepos/BAT.jl/src/samplers/mcmc/mcmc_tuner.jl:193
# ┌ Info: Selected 10 MCMC chain(s).
# └ @ BAT /Users/vhafych/MPP-Server/gitrepos/BAT.jl/src/samplers/mcmc/mcmc_tuner.jl:304
# ┌ Info: Begin tuning of 10 MCMC chain(s).
# └ @ BAT /Users/vhafych/MPP-Server/gitrepos/BAT.jl/src/samplers/mcmc/mcmc_tuner.jl:65
# ┌ Info: MCMC Tuning cycle 1 finished, 10 chains, 6 tuned, 0 converged.
# └ @ BAT /Users/vhafych/MPP-Server/gitrepos/BAT.jl/src/samplers/mcmc/mcmc_tuner.jl:98
# ┌ Info: MCMC Tuning cycle 2 finished, 10 chains, 7 tuned, 10 converged.
# └ @ BAT /Users/vhafych/MPP-Server/gitrepos/BAT.jl/src/samplers/mcmc/mcmc_tuner.jl:98
# ┌ Info: MCMC Tuning cycle 3 finished, 10 chains, 8 tuned, 10 converged.
# └ @ BAT /Users/vhafych/MPP-Server/gitrepos/BAT.jl/src/samplers/mcmc/mcmc_tuner.jl:98
# ┌ Info: MCMC Tuning cycle 4 finished, 10 chains, 9 tuned, 10 converged.
# └ @ BAT /Users/vhafych/MPP-Server/gitrepos/BAT.jl/src/samplers/mcmc/mcmc_tuner.jl:98
# ┌ Info: MCMC Tuning cycle 5 finished, 10 chains, 10 tuned, 10 converged.
# └ @ BAT /Users/vhafych/MPP-Server/gitrepos/BAT.jl/src/samplers/mcmc/mcmc_tuner.jl:98
# ┌ Info: MCMC tuning of 10 chains successful after 5 cycle(s).
# └ @ BAT /Users/vhafych/MPP-Server/gitrepos/BAT.jl/src/samplers/mcmc/mcmc_tuner.jl:102

# %%
mcmc_resampled = bat_sample(mcmc_sample, n_samples*n_chains).result;
# Out:
# ┌ Info: Initializing new RNG of type Random123.Philox4x{UInt64,10}
# └ @ BAT /Users/vhafych/MPP-Server/gitrepos/BAT.jl/src/algotypes/bat_default.jl:44
# ┌ Info: Using sampling algorithm OrderedResampling()
# └ @ BAT /Users/vhafych/MPP-Server/gitrepos/BAT.jl/src/algotypes/bat_default.jl:44

# %%
data_a = flatview(unshaped.(iid_sample.v));
data_b = flatview(unshaped.(mcmc_resampled.v));

x_d = hcat(data_a, data_b)
y_d = [repeat([0], size(data_a)[2]); repeat([1], size(data_b)[2])]
klasses = [0, 1]
onehot_labels = onehotbatch(y_d, klasses)

data_length = size(x_d)[2]

train_indices = [1:3:data_length; 2:3:data_length]
test_indices = collect(3:3:data_length)

x_train = x_d[:, train_indices]
y_train = onehot_labels[:,train_indices]

x_test = x_d[:, test_indices]
y_test = onehot_labels[:,test_indices]

train_data = Flux.Data.DataLoader(x_train, y_train, batchsize=256, shuffle=true);

# %%
model = Chain(Flux.Dense(n_dim, 20, sigmoid), Flux.Dense(20, 2), softmax)

optimiser = ADAM()

loss_test_f = Float64[]
loss_train_f = Float64[]

@time @epochs 200 Flux.train!(
    loss, 
    Flux.params(model), train_data, 
    optimiser, 
    cb = throttle(evalcb, 80)
);
# Out:
# ┌ Info: Epoch 1
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.7150601
# │   lost_test = 0.71463376
# └ @ Main In[36]:20
# ┌ Info: Epoch 2
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.69370073
# │   lost_test = 0.6940061
# └ @ Main In[36]:20
# ┌ Info: Epoch 3
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.692658
# │   lost_test = 0.6930109
# └ @ Main In[36]:20
# ┌ Info: Epoch 4
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6925968
# │   lost_test = 0.6928184
# └ @ Main In[36]:20
# ┌ Info: Epoch 5
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.69251996
# │   lost_test = 0.692845
# └ @ Main In[36]:20
# ┌ Info: Epoch 6
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.69200784
# │   lost_test = 0.6922701
# └ @ Main In[36]:20
# ┌ Info: Epoch 7
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.69168144
# │   lost_test = 0.6920877
# └ @ Main In[36]:20
# ┌ Info: Epoch 8
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.69162184
# │   lost_test = 0.69201195
# └ @ Main In[36]:20
# ┌ Info: Epoch 9
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6913246
# │   lost_test = 0.6916599
# └ @ Main In[36]:20
# ┌ Info: Epoch 10
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6914904
# │   lost_test = 0.6919669
# └ @ Main In[36]:20
# ┌ Info: Epoch 11
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.69078445
# │   lost_test = 0.69125783
# └ @ Main In[36]:20
# ┌ Info: Epoch 12
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6905448
# │   lost_test = 0.69114053
# └ @ Main In[36]:20
# ┌ Info: Epoch 13
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6903684
# │   lost_test = 0.69079834
# └ @ Main In[36]:20
# ┌ Info: Epoch 14
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6901898
# │   lost_test = 0.6909557
# └ @ Main In[36]:20
# ┌ Info: Epoch 15
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6897969
# │   lost_test = 0.69043106
# └ @ Main In[36]:20
# ┌ Info: Epoch 16
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6896284
# │   lost_test = 0.6903585
# └ @ Main In[36]:20
# ┌ Info: Epoch 17
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68958884
# │   lost_test = 0.69034535
# └ @ Main In[36]:20
# ┌ Info: Epoch 18
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68896806
# │   lost_test = 0.68972486
# └ @ Main In[36]:20
# ┌ Info: Epoch 19
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68889284
# │   lost_test = 0.6897936
# └ @ Main In[36]:20
# ┌ Info: Epoch 20
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68848616
# │   lost_test = 0.6894441
# └ @ Main In[36]:20
# ┌ Info: Epoch 21
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6884147
# │   lost_test = 0.68939817
# └ @ Main In[36]:20
# ┌ Info: Epoch 22
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6882374
# │   lost_test = 0.6893131
# └ @ Main In[36]:20
# ┌ Info: Epoch 23
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68811786
# │   lost_test = 0.6893411
# └ @ Main In[36]:20
# ┌ Info: Epoch 24
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68836546
# │   lost_test = 0.6895218
# └ @ Main In[36]:20
# ┌ Info: Epoch 25
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6874624
# │   lost_test = 0.68873715
# └ @ Main In[36]:20
# ┌ Info: Epoch 26
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6871553
# │   lost_test = 0.68847173
# └ @ Main In[36]:20
# ┌ Info: Epoch 27
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68760777
# │   lost_test = 0.6889402
# └ @ Main In[36]:20
# ┌ Info: Epoch 28
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68746394
# │   lost_test = 0.68896806
# └ @ Main In[36]:20
# ┌ Info: Epoch 29
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68658805
# │   lost_test = 0.6880782
# └ @ Main In[36]:20
# ┌ Info: Epoch 30
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68703955
# │   lost_test = 0.6885308
# └ @ Main In[36]:20
# ┌ Info: Epoch 31
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68631226
# │   lost_test = 0.68799096
# └ @ Main In[36]:20
# ┌ Info: Epoch 32
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.686155
# │   lost_test = 0.68787324
# └ @ Main In[36]:20
# ┌ Info: Epoch 33
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6862351
# │   lost_test = 0.6880056
# └ @ Main In[36]:20
# ┌ Info: Epoch 34
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6860699
# │   lost_test = 0.68790776
# └ @ Main In[36]:20
# ┌ Info: Epoch 35
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68584466
# │   lost_test = 0.68765926
# └ @ Main In[36]:20
# ┌ Info: Epoch 36
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6856454
# │   lost_test = 0.6875931
# └ @ Main In[36]:20
# ┌ Info: Epoch 37
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68606883
# │   lost_test = 0.68796766
# └ @ Main In[36]:20
# ┌ Info: Epoch 38
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6853316
# │   lost_test = 0.6873801
# └ @ Main In[36]:20
# ┌ Info: Epoch 39
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6852882
# │   lost_test = 0.68731236
# └ @ Main In[36]:20
# ┌ Info: Epoch 40
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6853006
# │   lost_test = 0.68722117
# └ @ Main In[36]:20
# ┌ Info: Epoch 41
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6850814
# │   lost_test = 0.68717635
# └ @ Main In[36]:20
# ┌ Info: Epoch 42
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68491316
# │   lost_test = 0.68715745
# └ @ Main In[36]:20
# ┌ Info: Epoch 43
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68490565
# │   lost_test = 0.6871935
# └ @ Main In[36]:20
# ┌ Info: Epoch 44
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6856709
# │   lost_test = 0.68791527
# └ @ Main In[36]:20
# ┌ Info: Epoch 45
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6849821
# │   lost_test = 0.6873682
# └ @ Main In[36]:20
# ┌ Info: Epoch 46
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68508494
# │   lost_test = 0.68740624
# └ @ Main In[36]:20
# ┌ Info: Epoch 47
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6848924
# │   lost_test = 0.687327
# └ @ Main In[36]:20
# ┌ Info: Epoch 48
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6845318
# │   lost_test = 0.686985
# └ @ Main In[36]:20
# ┌ Info: Epoch 49
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68448937
# │   lost_test = 0.68696535
# └ @ Main In[36]:20
# ┌ Info: Epoch 50
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68466264
# │   lost_test = 0.6871487
# └ @ Main In[36]:20
# ┌ Info: Epoch 51
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6843836
# │   lost_test = 0.686921
# └ @ Main In[36]:20
# ┌ Info: Epoch 52
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68505746
# │   lost_test = 0.6877509
# └ @ Main In[36]:20
# ┌ Info: Epoch 53
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6842514
# │   lost_test = 0.68676287
# └ @ Main In[36]:20
# ┌ Info: Epoch 54
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6842214
# │   lost_test = 0.68679565
# └ @ Main In[36]:20
# ┌ Info: Epoch 55
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6846829
# │   lost_test = 0.687253
# └ @ Main In[36]:20
# ┌ Info: Epoch 56
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.684465
# │   lost_test = 0.68733597
# └ @ Main In[36]:20
# ┌ Info: Epoch 57
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6840719
# │   lost_test = 0.6866409
# └ @ Main In[36]:20
# ┌ Info: Epoch 58
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68408424
# │   lost_test = 0.6868252
# └ @ Main In[36]:20
# ┌ Info: Epoch 59
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6840758
# │   lost_test = 0.68686604
# └ @ Main In[36]:20
# ┌ Info: Epoch 60
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6839342
# │   lost_test = 0.68664646
# └ @ Main In[36]:20
# ┌ Info: Epoch 61
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.684101
# │   lost_test = 0.6868812
# └ @ Main In[36]:20
# ┌ Info: Epoch 62
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6837973
# │   lost_test = 0.68653834
# └ @ Main In[36]:20
# ┌ Info: Epoch 63
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6843882
# │   lost_test = 0.6872044
# └ @ Main In[36]:20
# ┌ Info: Epoch 64
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6837303
# │   lost_test = 0.6865223
# └ @ Main In[36]:20
# ┌ Info: Epoch 65
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68378633
# │   lost_test = 0.6866052
# └ @ Main In[36]:20
# ┌ Info: Epoch 66
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6838169
# │   lost_test = 0.6867203
# └ @ Main In[36]:20
# ┌ Info: Epoch 67
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6836633
# │   lost_test = 0.686399
# └ @ Main In[36]:20
# ┌ Info: Epoch 68
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6837022
# │   lost_test = 0.686584
# └ @ Main In[36]:20
# ┌ Info: Epoch 69
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6838146
# │   lost_test = 0.68660766
# └ @ Main In[36]:20
# ┌ Info: Epoch 70
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68375236
# │   lost_test = 0.6864413
# └ @ Main In[36]:20
# ┌ Info: Epoch 71
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68372315
# │   lost_test = 0.68653965
# └ @ Main In[36]:20
# ┌ Info: Epoch 72
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6837972
# │   lost_test = 0.68673164
# └ @ Main In[36]:20
# ┌ Info: Epoch 73
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68424064
# │   lost_test = 0.68716973
# └ @ Main In[36]:20
# ┌ Info: Epoch 74
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.683755
# │   lost_test = 0.6867285
# └ @ Main In[36]:20
# ┌ Info: Epoch 75
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.683952
# │   lost_test = 0.686929
# └ @ Main In[36]:20
# ┌ Info: Epoch 76
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68371975
# │   lost_test = 0.6866328
# └ @ Main In[36]:20
# ┌ Info: Epoch 77
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6834263
# │   lost_test = 0.68640345
# └ @ Main In[36]:20
# ┌ Info: Epoch 78
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68374825
# │   lost_test = 0.6867195
# └ @ Main In[36]:20
# ┌ Info: Epoch 79
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68334293
# │   lost_test = 0.686372
# └ @ Main In[36]:20
# ┌ Info: Epoch 80
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6835428
# │   lost_test = 0.6865556
# └ @ Main In[36]:20
# ┌ Info: Epoch 81
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6835276
# │   lost_test = 0.6865455
# └ @ Main In[36]:20
# ┌ Info: Epoch 82
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6833485
# │   lost_test = 0.686516
# └ @ Main In[36]:20
# ┌ Info: Epoch 83
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6832042
# │   lost_test = 0.6862558
# └ @ Main In[36]:20
# ┌ Info: Epoch 84
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6836571
# │   lost_test = 0.6866967
# └ @ Main In[36]:20
# ┌ Info: Epoch 85
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6833311
# │   lost_test = 0.6863884
# └ @ Main In[36]:20
# ┌ Info: Epoch 86
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6831795
# │   lost_test = 0.68627596
# └ @ Main In[36]:20
# ┌ Info: Epoch 87
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68383163
# │   lost_test = 0.6870823
# └ @ Main In[36]:20
# ┌ Info: Epoch 88
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68322676
# │   lost_test = 0.68641657
# └ @ Main In[36]:20
# ┌ Info: Epoch 89
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6833832
# │   lost_test = 0.6865423
# └ @ Main In[36]:20
# ┌ Info: Epoch 90
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68314755
# │   lost_test = 0.68635803
# └ @ Main In[36]:20
# ┌ Info: Epoch 91
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6831481
# │   lost_test = 0.6862106
# └ @ Main In[36]:20
# ┌ Info: Epoch 92
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6831522
# │   lost_test = 0.6863773
# └ @ Main In[36]:20
# ┌ Info: Epoch 93
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6829582
# │   lost_test = 0.68625116
# └ @ Main In[36]:20
# ┌ Info: Epoch 94
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6829197
# │   lost_test = 0.68621254
# └ @ Main In[36]:20
# ┌ Info: Epoch 95
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6833181
# │   lost_test = 0.686625
# └ @ Main In[36]:20
# ┌ Info: Epoch 96
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6831665
# │   lost_test = 0.6862997
# └ @ Main In[36]:20
# ┌ Info: Epoch 97
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6835002
# │   lost_test = 0.6867665
# └ @ Main In[36]:20
# ┌ Info: Epoch 98
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.683088
# │   lost_test = 0.68636817
# └ @ Main In[36]:20
# ┌ Info: Epoch 99
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6830319
# │   lost_test = 0.6862849
# └ @ Main In[36]:20
# ┌ Info: Epoch 100
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6830208
# │   lost_test = 0.68623286
# └ @ Main In[36]:20
# ┌ Info: Epoch 101
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6828653
# │   lost_test = 0.6863399
# └ @ Main In[36]:20
# ┌ Info: Epoch 102
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68305856
# │   lost_test = 0.68628305
# └ @ Main In[36]:20
# ┌ Info: Epoch 103
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68297905
# │   lost_test = 0.6863543
# └ @ Main In[36]:20
# ┌ Info: Epoch 104
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6829445
# │   lost_test = 0.686357
# └ @ Main In[36]:20
# ┌ Info: Epoch 105
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6828335
# │   lost_test = 0.686213
# └ @ Main In[36]:20
# ┌ Info: Epoch 106
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68290824
# │   lost_test = 0.6861442
# └ @ Main In[36]:20
# ┌ Info: Epoch 107
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68286186
# │   lost_test = 0.6861003
# └ @ Main In[36]:20
# ┌ Info: Epoch 108
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68271613
# │   lost_test = 0.6861121
# └ @ Main In[36]:20
# ┌ Info: Epoch 109
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6827067
# │   lost_test = 0.6859371
# └ @ Main In[36]:20
# ┌ Info: Epoch 110
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.682804
# │   lost_test = 0.68618023
# └ @ Main In[36]:20
# ┌ Info: Epoch 111
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6826068
# │   lost_test = 0.6861345
# └ @ Main In[36]:20
# ┌ Info: Epoch 112
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6827079
# │   lost_test = 0.68614703
# └ @ Main In[36]:20
# ┌ Info: Epoch 113
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68284917
# │   lost_test = 0.6862906
# └ @ Main In[36]:20
# ┌ Info: Epoch 114
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6825779
# │   lost_test = 0.68604016
# └ @ Main In[36]:20
# ┌ Info: Epoch 115
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68308556
# │   lost_test = 0.68672425
# └ @ Main In[36]:20
# ┌ Info: Epoch 116
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68263817
# │   lost_test = 0.6861113
# └ @ Main In[36]:20
# ┌ Info: Epoch 117
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6824498
# │   lost_test = 0.6859087
# └ @ Main In[36]:20
# ┌ Info: Epoch 118
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6828932
# │   lost_test = 0.6865979
# └ @ Main In[36]:20
# ┌ Info: Epoch 119
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6825693
# │   lost_test = 0.6861537
# └ @ Main In[36]:20
# ┌ Info: Epoch 120
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68244016
# │   lost_test = 0.6860195
# └ @ Main In[36]:20
# ┌ Info: Epoch 121
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6823671
# │   lost_test = 0.68590766
# └ @ Main In[36]:20
# ┌ Info: Epoch 122
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68258667
# │   lost_test = 0.6862147
# └ @ Main In[36]:20
# ┌ Info: Epoch 123
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6825428
# │   lost_test = 0.68606544
# └ @ Main In[36]:20
# ┌ Info: Epoch 124
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6822824
# │   lost_test = 0.6858713
# └ @ Main In[36]:20
# ┌ Info: Epoch 125
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6822759
# │   lost_test = 0.68599033
# └ @ Main In[36]:20
# ┌ Info: Epoch 126
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68246186
# │   lost_test = 0.68619204
# └ @ Main In[36]:20
# ┌ Info: Epoch 127
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6822589
# │   lost_test = 0.6858195
# └ @ Main In[36]:20
# ┌ Info: Epoch 128
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6827954
# │   lost_test = 0.68637645
# └ @ Main In[36]:20
# ┌ Info: Epoch 129
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6828761
# │   lost_test = 0.68641764
# └ @ Main In[36]:20
# ┌ Info: Epoch 130
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68223864
# │   lost_test = 0.68604386
# └ @ Main In[36]:20
# ┌ Info: Epoch 131
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68259513
# │   lost_test = 0.68615174
# └ @ Main In[36]:20
# ┌ Info: Epoch 132
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6823022
# │   lost_test = 0.68620074
# └ @ Main In[36]:20
# ┌ Info: Epoch 133
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68241566
# │   lost_test = 0.68605685
# └ @ Main In[36]:20
# ┌ Info: Epoch 134
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6821605
# │   lost_test = 0.68606085
# └ @ Main In[36]:20
# ┌ Info: Epoch 135
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6821547
# │   lost_test = 0.6859637
# └ @ Main In[36]:20
# ┌ Info: Epoch 136
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6820272
# │   lost_test = 0.68596786
# └ @ Main In[36]:20
# ┌ Info: Epoch 137
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6821653
# │   lost_test = 0.6861001
# └ @ Main In[36]:20
# ┌ Info: Epoch 138
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6825746
# │   lost_test = 0.68630564
# └ @ Main In[36]:20
# ┌ Info: Epoch 139
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68257546
# │   lost_test = 0.6866013
# └ @ Main In[36]:20
# ┌ Info: Epoch 140
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68196887
# │   lost_test = 0.68585163
# └ @ Main In[36]:20
# ┌ Info: Epoch 141
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6824425
# │   lost_test = 0.68652385
# └ @ Main In[36]:20
# ┌ Info: Epoch 142
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6823689
# │   lost_test = 0.6864149
# └ @ Main In[36]:20
# ┌ Info: Epoch 143
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68205035
# │   lost_test = 0.6858943
# └ @ Main In[36]:20
# ┌ Info: Epoch 144
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68200696
# │   lost_test = 0.68594617
# └ @ Main In[36]:20
# ┌ Info: Epoch 145
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.681907
# │   lost_test = 0.6859801
# └ @ Main In[36]:20
# ┌ Info: Epoch 146
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68213445
# │   lost_test = 0.68609184
# └ @ Main In[36]:20
# ┌ Info: Epoch 147
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.682232
# │   lost_test = 0.68634135
# └ @ Main In[36]:20
# ┌ Info: Epoch 148
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68204963
# │   lost_test = 0.6859506
# └ @ Main In[36]:20
# ┌ Info: Epoch 149
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68206847
# │   lost_test = 0.68604934
# └ @ Main In[36]:20
# ┌ Info: Epoch 150
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6817997
# │   lost_test = 0.68584776
# └ @ Main In[36]:20
# ┌ Info: Epoch 151
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68198645
# │   lost_test = 0.6859948
# └ @ Main In[36]:20
# ┌ Info: Epoch 152
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6820325
# │   lost_test = 0.68590724
# └ @ Main In[36]:20
# ┌ Info: Epoch 153
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68186957
# │   lost_test = 0.6859078
# └ @ Main In[36]:20
# ┌ Info: Epoch 154
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68183786
# │   lost_test = 0.68591076
# └ @ Main In[36]:20
# ┌ Info: Epoch 155
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68218917
# │   lost_test = 0.6862024
# └ @ Main In[36]:20
# ┌ Info: Epoch 156
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68182045
# │   lost_test = 0.68604964
# └ @ Main In[36]:20
# ┌ Info: Epoch 157
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6818703
# │   lost_test = 0.68580514
# └ @ Main In[36]:20
# ┌ Info: Epoch 158
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68172747
# │   lost_test = 0.68593407
# └ @ Main In[36]:20
# ┌ Info: Epoch 159
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68205154
# │   lost_test = 0.68609804
# └ @ Main In[36]:20
# ┌ Info: Epoch 160
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6819685
# │   lost_test = 0.68621856
# └ @ Main In[36]:20
# ┌ Info: Epoch 161
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6817378
# │   lost_test = 0.6857835
# └ @ Main In[36]:20
# ┌ Info: Epoch 162
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6821527
# │   lost_test = 0.6863387
# └ @ Main In[36]:20
# ┌ Info: Epoch 163
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68167454
# │   lost_test = 0.6858459
# └ @ Main In[36]:20
# ┌ Info: Epoch 164
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.681719
# │   lost_test = 0.6859679
# └ @ Main In[36]:20
# ┌ Info: Epoch 165
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68175256
# │   lost_test = 0.6858979
# └ @ Main In[36]:20
# ┌ Info: Epoch 166
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6817461
# │   lost_test = 0.6858381
# └ @ Main In[36]:20
# ┌ Info: Epoch 167
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6820208
# │   lost_test = 0.6863527
# └ @ Main In[36]:20
# ┌ Info: Epoch 168
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6826556
# │   lost_test = 0.68693054
# └ @ Main In[36]:20
# ┌ Info: Epoch 169
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68156767
# │   lost_test = 0.6857909
# └ @ Main In[36]:20
# ┌ Info: Epoch 170
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6818362
# │   lost_test = 0.6858217
# └ @ Main In[36]:20
# ┌ Info: Epoch 171
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68181086
# │   lost_test = 0.6860046
# └ @ Main In[36]:20
# ┌ Info: Epoch 172
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68160015
# │   lost_test = 0.68566203
# └ @ Main In[36]:20
# ┌ Info: Epoch 173
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68176264
# │   lost_test = 0.68584204
# └ @ Main In[36]:20
# ┌ Info: Epoch 174
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6815272
# │   lost_test = 0.68570566
# └ @ Main In[36]:20
# ┌ Info: Epoch 175
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68187463
# │   lost_test = 0.68603987
# └ @ Main In[36]:20
# ┌ Info: Epoch 176
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68157965
# │   lost_test = 0.6856562
# └ @ Main In[36]:20
# ┌ Info: Epoch 177
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.681708
# │   lost_test = 0.6858041
# └ @ Main In[36]:20
# ┌ Info: Epoch 178
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6819541
# │   lost_test = 0.6861011
# └ @ Main In[36]:20
# ┌ Info: Epoch 179
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6816158
# │   lost_test = 0.6858046
# └ @ Main In[36]:20
# ┌ Info: Epoch 180
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6816657
# │   lost_test = 0.6856973
# └ @ Main In[36]:20
# ┌ Info: Epoch 181
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68151295
# │   lost_test = 0.6857555
# └ @ Main In[36]:20
# ┌ Info: Epoch 182
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68194157
# │   lost_test = 0.6860869
# └ @ Main In[36]:20
# ┌ Info: Epoch 183
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68174607
# │   lost_test = 0.68594396
# └ @ Main In[36]:20
# ┌ Info: Epoch 184
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68188393
# │   lost_test = 0.685912
# └ @ Main In[36]:20
# ┌ Info: Epoch 185
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6815511
# │   lost_test = 0.68580955
# └ @ Main In[36]:20
# ┌ Info: Epoch 186
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68196166
# │   lost_test = 0.6860414
# └ @ Main In[36]:20
# ┌ Info: Epoch 187
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6814606
# │   lost_test = 0.68556714
# └ @ Main In[36]:20
# ┌ Info: Epoch 188
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68170524
# │   lost_test = 0.68580997
# └ @ Main In[36]:20
# ┌ Info: Epoch 189
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68186706
# │   lost_test = 0.68619215
# └ @ Main In[36]:20
# ┌ Info: Epoch 190
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6815724
# │   lost_test = 0.6858143
# └ @ Main In[36]:20
# ┌ Info: Epoch 191
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68161345
# │   lost_test = 0.68585867
# └ @ Main In[36]:20
# ┌ Info: Epoch 192
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6814831
# │   lost_test = 0.6857189
# └ @ Main In[36]:20
# ┌ Info: Epoch 193
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6814744
# │   lost_test = 0.6857993
# └ @ Main In[36]:20
# ┌ Info: Epoch 194
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68143064
# │   lost_test = 0.68555504
# └ @ Main In[36]:20
# ┌ Info: Epoch 195
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.681658
# │   lost_test = 0.6857061
# └ @ Main In[36]:20
# ┌ Info: Epoch 196
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6815577
# │   lost_test = 0.68579996
# └ @ Main In[36]:20
# ┌ Info: Epoch 197
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68184906
# │   lost_test = 0.6859462
# └ @ Main In[36]:20
# ┌ Info: Epoch 198
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68144816
# │   lost_test = 0.68569905
# └ @ Main In[36]:20
# ┌ Info: Epoch 199
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.6815584
# │   lost_test = 0.6857158
# └ @ Main In[36]:20
# ┌ Info: Epoch 200
# └ @ Main /Users/vhafych/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# ┌ Info: 0.68144053
# │   lost_test = 0.6856677
# └ @ Main In[36]:20
# 233.437348 seconds (2.87 G allocations: 83.029 GiB, 5.45% gc time)

# %%
accuracy_score = accuracy(x_test, y_test, model)
# Out:
# 0.546840533605438

# %%
fig, ax = plt.subplots(1,1, figsize=(4,3))

x_tmp = model(x_test)[1,:]
y_tmp = model(x_test)[2,:]
ax.hist(x_tmp, bins=100, alpha=0.5)
ax.hist(y_tmp, bins=100, alpha=0.5);
# Out:
# Figure(PyObject <Figure size 400x300 with 1 Axes>)

# %%
ApproximateTwoSampleKSTest(x_tmp, y_tmp)
# Out:
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/vhafych/.julia/packages/HypothesisTests/5rgiE/src/kolmogorov_smirnov.jl:167
# Approximate two sample Kolmogorov-Smirnov test
# ----------------------------------------------
# Population details:
#     parameter of interest:   Supremum of CDF differences
#     value under h_0:         0.0
#     point estimate:          0.01829204243633799
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-9
#
# Details:
#     number of observations:   [66641,66641]
#     KS-statistic:              3.3390118096448846

# %%
c_range = 0.0:0.005:1

function def_roc_vals(ind1, ind2; c_range = c_range)

    tA_array = Float64[]
    fA_array = Float64[]

    for c in c_range

        t_A = y_test[ind1,:]
        t_B = y_test[ind2,:]

        p = softmax(model(x_test), dims=1) .> c

        p_A = p[ind1,:]
        p_B = p[ind2,:]

        true_A = sum(t_A.*p_A)/sum(t_A)
        false_A = sum(.!t_A.*p_A) / sum(t_B)

        append!(tA_array, true_A)
        append!(fA_array, false_A)
    end
    
    return (fA_array, tA_array)
    
end

A_f, A_t = def_roc_vals(1, 2)

colors_a = plt.cm.terrain(range(0, stop=1, length = length(c_range)));

fig, ax = plt.subplots(1,1, figsize=(4,4))
ax.scatter(A_f, A_t, alpha=0.5, color=PyPlot.ColorMap("tab10").colors[1])
ax.plot(0:0.1:1, 0:0.1:1, color="gray")
ax.set_xlabel("False Positive Rate")
ax.set_ylabel("True Positive Rate")
ax.set_xlim(-0.1,1.1)
ax.set_ylim(-0.1,1.1)
# Out:
# Figure(PyObject <Figure size 400x400 with 1 Axes>)
# (-0.1, 1.1)

# %%
dim = 3

fig, ax = plt.subplots(1,1, figsize=(4,3))

ax.hist(data_a[dim,:], bins=range(-2, stop=2, length=50), alpha=0.5, label="iid")
ax.hist(data_b[dim,:], bins=range(-2, stop=2, length=50), alpha=0.5, label="mcmc")

# ax.set_xlim(-5, 50)

ax.legend()
# Out:
# Figure(PyObject <Figure size 400x300 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x7f87b47dfed0>
