# %%
using PyPlot

# %%
SMALL_SIZE = 9
MEDIUM_SIZE = 10
BIGGER_SIZE = 10

plt.rc("font", size=SMALL_SIZE)          # controls default text sizes
plt.rc("axes", titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc("axes", labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc("xtick", labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc("ytick", labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc("legend", fontsize=SMALL_SIZE)    # legend fontsize
plt.rc("figure", titlesize=BIGGER_SIZE)  # fontsize of the figure title
# plt.rc("text", usetex=true)

# %%
latex_width = 421.10046

fractions = (1, 0.6)
# Out:
# (1, 0.6)

# %%
# https://jwalton.info/Embed-Publication-Matplotlib-Latex/

function set_size(width; fraction=1)
    """Set figure dimensions to avoid scaling in LaTeX.

    Parameters
    ----------
    width: float
            Document textwidth or columnwidth in pts
    fraction: float, optional
            Fraction of the width which you wish the figure to occupy

    Returns
    -------
    fig_dim: tuple
            Dimensions of figure in inches
    """
    # Width of figure (in pts)
    fig_width_pt = width * fraction

    # Convert from pt to inches
    inches_per_pt = 1 / 72.27

    # Golden ratio to set aesthetic figure height
    # https://disq.us/p/2940ij3
    golden_ratio = (5^0.5 - 1) / 2

    # Figure width in inches
    fig_width_in = fig_width_pt * inches_per_pt
    # Figure height in inches
    fig_height_in = fig_width_in * golden_ratio

    fig_dim = (fig_width_in, fig_height_in)

    return fig_dim
end

set_size(latex_width, fraction=1)
# Out:
# (5.826767123287671, 3.60114012672223)

# %%
function set_size(width; fraction=1, subplots=(1, 1))
    """Set figure dimensions to avoid scaling in LaTeX.

    Parameters
    ----------
    width: float or string
            Document width in points, or string of predined document type
    fraction: float, optional
            Fraction of the width which you wish the figure to occupy
    subplots: array-like, optional
            The number of rows and columns of subplots.
    Returns
    -------
    fig_dim: tuple
            Dimensions of figure in inches
    """
    width_pt = width

    # Width of figure (in pts)
    fig_width_pt = width_pt * fraction
    # Convert from pt to inches
    inches_per_pt = 1 / 72.27

    # Golden ratio to set aesthetic figure height
    # https://disq.us/p/2940ij3
    golden_ratio = (5^0.5 - 1) / 2

    # Figure width in inches
    fig_width_in = fig_width_pt * inches_per_pt
    # Figure height in inches
    fig_height_in = fig_width_in * golden_ratio * (subplots[1] / subplots[2])

    return (fig_width_in, fig_height_in)
end

set_size(latex_width, fraction=1, subplots=(1, 2)) # (rows, col)
# Out:
# (5.826767123287671, 1.800570063361115)

# %%
fig, ax = plt.subplots(1, 1, figsize=set_size(latex_width, fraction=1))

ax.plot(x, sin.(x), label="1 hdrn")
ax.set_xlim(0, 2 * 3)
ax.set_xlabel("# Subspaces")
ax.set_ylabel("Total CPU Time Speedup")
ax.legend()

fig.savefig("test-1.pdf", bbox_inches = "tight")
# Out:
# Figure(PyObject <Figure size 582.677x360.114 with 1 Axes>)

# %%
fig, ax = plt.subplots(1, 1, figsize=set_size(latex_width, fraction=0.6))

ax.plot(x, sin.(x))
ax.set_xlim(0, 2 * 3)

ax.set_xlabel("# Subspaces")
ax.set_ylabel("Total CPU Time Speedup")

fig.savefig("test-2.pdf", bbox_inches = "tight")
# Out:
# Figure(PyObject <Figure size 349.606x216.068 with 1 Axes>)

# %%
fig, (ax, ax2) = plt.subplots(1, 2, figsize=set_size(latex_width, fraction=1, subplots=(1, 2)))

ax.plot(x, sin.(x))
ax.set_xlim(0, 2 * 3)

ax.set_xlabel("# Subspaces")
ax.set_ylabel("Total CPU Time")

fig.savefig("test-3.pdf", bbox_inches = "tight")
# Out:
# Figure(PyObject <Figure size 582.677x180.057 with 2 Axes>)

# %%
set_size(latex_width, fraction=0.6, subplots=(1, 2))
# Out:
# (3.4960602739726023, 1.0803420380166688)

# %%
fig, (ax, ax2) = plt.subplots(2, 1, figsize=set_size(latex_width, fraction=0.6, subplots=(2, 1)))

ax.plot(x, sin.(x))
ax.set_xlim(0, 2 * 3)

ax.set_xlabel("# Subspaces")
ax.set_ylabel("Total CPU Time")

fig.savefig("test-3.pdf", bbox_inches = "tight")
# Out:
# Figure(PyObject <Figure size 349.606x432.137 with 2 Axes>)
